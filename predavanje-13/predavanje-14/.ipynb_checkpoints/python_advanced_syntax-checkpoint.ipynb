# %%
def foo(*b):
    product = 1
    for el in b:
        product *= el
    return product

# %%
foo(3,6,5)
# Out:
# 90

# %%
# args i kwargs

# %%
def boo(**kwargs):

# %%
boo(ime='Janko',prezime='Jankovic')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ac7dacd6870c> in <module>
# ----> 1 boo(ime='Janko',prezime='Jankovic')
#
# TypeError: boo() got an unexpected keyword argument 'ime'
