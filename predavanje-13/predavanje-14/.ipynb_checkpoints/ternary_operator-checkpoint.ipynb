# %%
to_check=11

msg = ""

if to_check%2 == 0:
  msg = "Even"
else:
  msg = "Odd"
print(msg)
# Out:
# Odd

# %%
# - uslov
# - vrijednost ako je tacno
# - vrijednost ako je netacno

# %%
'Even' if to_check % 2 == 0 else 'Odd'

# %%
msg
# Out:
# 'Odd'

# %%
lista = ['Joe', 'Donovan', 'Sara', 'Ana']
i = 0
for ime in lista:
    print(i, ime)
    i+=1
# Out:
# 0 Joe
# 1 Donovan
# 2 Sara
# 3 Ana
